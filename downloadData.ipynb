# %% [markdown]
# # First appraoches

# %%
from nba_api.stats.endpoints import leaguedashplayerclutch
import inspect

# Print the parameters accepted by LeagueDashPlayerClutch
print(inspect.signature(leaguedashplayerclutch.LeagueDashPlayerClutch.__init__))
# Out:
# (self, ahead_behind='Ahead or Behind', clutch_time='Last 5 Minutes', last_n_games='0', measure_type_detailed_defense='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', point_diff='5', rank='N', season='2024-25', season_type_all_star='Regular Season', college_nullable='', conference_nullable='', country_nullable='', date_from_nullable='', date_to_nullable='', division_simple_nullable='', draft_pick_nullable='', draft_year_nullable='', game_scope_simple_nullable='', game_segment_nullable='', height_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', player_experience_nullable='', player_position_abbreviation_nullable='', season_segment_nullable='', shot_clock_range_nullable='', starter_bench_nullable='', team_id_nullable='', vs_conference_nullable='', vs_division_nullable='', weight_nullable='', proxy=None, headers=None, timeout=30, get_request=True)

# %%
from nba_api.stats.endpoints import leaguedashplayerclutch
import pandas as pd

# Get clutch stats with the correct parameters
clutch_stats = leaguedashplayerclutch.LeagueDashPlayerClutch(
    ahead_behind='Ahead or Behind',
    clutch_time='Last 5 Minutes',
    point_diff='5',
    season='2023-24',
    season_type_all_star='Regular Season',
    measure_type_detailed_defense='Base',
    per_mode_detailed='PerGame'
)

# Convert to DataFrame
clutch_df = clutch_stats.get_data_frames()[0]

# %%
clutch_df.shape
# Out:
# (469, 67)

# %% [markdown]
# # Get all clutch plays and select top performers

# %%
from nba_api.stats.endpoints import leaguedashplayerclutch
import pandas as pd
import time
import random

def get_clutch_stats_for_season(season='2023-24', season_chunk="Regular Season", min_minutes=0, min_min = 1):
    """
    Get clutch stats for all players in a given season with no filtering
    
    Parameters:
    season (str): Season in format '2023-24'
    min_minutes (float): Minimum clutch minutes to include (0 = no filtering)
    
    Returns:
    pandas.DataFrame: DataFrame with clutch stats for all players
    """
    try:
        print(f"Fetching clutch stats for season {season}...")
        
        # Parameters for clutch time (last 5 min, game within 5 points)
        clutch_stats = leaguedashplayerclutch.LeagueDashPlayerClutch(
            season=season,
            season_type_all_star=season_chunk,
            measure_type_detailed_defense='Advanced',
            clutch_time='Last 5 Minutes',
            point_diff='5',
            per_mode_detailed='Totals'  # Get total stats instead of per game
        )
        
        # Get the data
        df = clutch_stats.get_data_frames()[0]
        
        # Force the SEASON column
        df['SEASON'] = season
        
        # Filter for minimum minutes if specified
        if min_minutes > 0:
            filtered_df = df[df['MIN'] >= min_minutes].copy()
            filtered_df = filtered_df[filtered_df['MIN'] >= min_min]
            print(f"Found {len(filtered_df)} players with ≥{min_minutes} clutch minutes in {season} (filtered from {len(df)} total)")
        else:
            filtered_df = df.copy()
            print(f"Found {len(filtered_df)} players with clutch data in {season}")
        
        return filtered_df
        
    except Exception as e:
        print(f"Error getting clutch stats for season {season}: {e}")
        import traceback
        traceback.print_exc()
        return None

def process_multiple_seasons(start_year, end_year):
    """
    Process multiple seasons of clutch data with no intermediate saving
    
    Parameters:
    start_year (int): Starting year (e.g., 2018 for 2018-19 season)
    end_year (int): Ending year (e.g., 2023 for 2023-24 season)
    
    Returns:
    pandas.DataFrame: Combined DataFrame with clutch stats for all seasons
    """
    all_seasons_data = []
    
    for year in range(start_year, end_year + 1):
        # Create season string (e.g., '2023-24')
        season = f"{year}-{str(year+1)[-2:]}"
        
        print(f"\n=== Processing {season} season ===")
        
        # Get clutch stats for this season - no minimum minutes filter
        season_data = get_clutch_stats_for_season(season, min_minutes=1)
        
        if season_data is not None and not season_data.empty:
            # Add to the combined data
            all_seasons_data.append(season_data)
            
            print(f"Added {len(season_data)} players from {season} to dataset")
            
            # Add delay between seasons to avoid rate limiting
            if year < end_year:
                delay = random.uniform(2, 4)
                print(f"Waiting {delay:.2f} seconds before next season...")
                time.sleep(delay)
        else:
            print(f"No data collected for {season}")
    
    # Combine all seasons
    if all_seasons_data:
        combined_data = pd.concat(all_seasons_data, ignore_index=True)
        print(f"\nTotal: {len(combined_data)} player-season records across {len(all_seasons_data)} seasons")
        return combined_data
    else:
        print(f"No data collected for any seasons")
        return pd.DataFrame()

def get_top_clutch_performers(df, n=50, min_games=10, min_min=1):
    """
    Get top clutch performers from a DataFrame with more robust filtering
    
    Parameters:
    df (pandas.DataFrame): DataFrame with clutch stats
    n (int): Number of top performers to return
    min_games (int): Minimum games played in clutch situations
    
    Returns:
    pandas.DataFrame: DataFrame with top clutch performers
    """
    # Filter for minimum games played
    filtered_df = df[df['GP'] >= min_games].copy()
    filtered_df = filtered_df[filtered_df['MIN'] >= min_min]

    
    print(f"Filtering for players with at least {min_games} clutch games")
    print(f"Before: {len(df)} players, After: {len(filtered_df)} players")
    
    # Sort by clutch impact score and get top n
    top_players = filtered_df.sort_values('NET_RATING', ascending=False).head(n)
    
    # Select relevant columns for display
    display_cols = [
        'PLAYER_NAME', 'TEAM_ABBREVIATION', 'SEASON', 
        'GP', 'MIN', 'NET_RATING', 'OFF_RATING', 'DEF_RATING',
        'USG_PCT', 'TS_PCT', 'PIE'
    ]
    
    # Get columns that exist in the DataFrame
    available_cols = [col for col in display_cols if col in top_players.columns]
    
    return top_players[available_cols]

# %%
# Example usage
# Get data for multiple seasons (with no intermediate saving)
all_data = process_multiple_seasons(2018, 2023)

if not all_data.empty:
    # Get top clutch performers across all seasons (min 10 games)
    top_performers = get_top_clutch_performers(all_data, n=50, min_games=10)
    
    print("\nTop 50 Clutch Performers (2018-2023) with at least 10 clutch games:")
    print(top_performers)
    
    # Save only the final results
    final_filename = "top_clutch_performers_2018-2023.csv"
    top_performers.to_csv(final_filename, index=False)
    print(f"Saved top performers to {final_filename}")
    
    # Also save the complete dataset
    complete_filename = "all_clutch_data_2018-2023.csv"
    all_data.to_csv(complete_filename, index=False)
    print(f"Saved complete dataset to {complete_filename}")
# Out:
# === Processing 2018-19 season ===
# Fetching clutch stats for season 2018-19...
# Found 451 players with clutch data in 2018-19
# Added 451 players from 2018-19 to dataset
# Waiting 3.59 seconds before next season...
#
# === Processing 2019-20 season ===
# Fetching clutch stats for season 2019-20...
# Found 456 players with clutch data in 2019-20
# Added 456 players from 2019-20 to dataset
# Waiting 3.40 seconds before next season...
#
# === Processing 2020-21 season ===
# Fetching clutch stats for season 2020-21...
# Found 454 players with clutch data in 2020-21
# Added 454 players from 2020-21 to dataset
# Waiting 2.49 seconds before next season...
#
# === Processing 2021-22 season ===
# Fetching clutch stats for season 2021-22...
# Found 496 players with clutch data in 2021-22
# Added 496 players from 2021-22 to dataset
# Waiting 2.52 seconds before next season...
#
# === Processing 2022-23 season ===
# Fetching clutch stats for season 2022-23...
# Found 451 players with clutch data in 2022-23
# Added 451 players from 2022-23 to dataset
# Waiting 2.71 seconds before next season...
#
# === Processing 2023-24 season ===
# Fetching clutch stats for season 2023-24...
# Found 469 players with clutch data in 2023-24
# Added 469 players from 2023-24 to dataset
#
# Total: 2777 player-season records across 6 seasons
# Filtering for players with at least 10 clutch games
# Before: 2777 players, After: 1640 players
#
# Top 50 Clutch Performers (2018-2023) with at least 10 clutch games:
#                 PLAYER_NAME TEAM_ABBREVIATION   SEASON  GP  MIN  NET_RATING  \
# 2325         Andre Drummond               CHI  2023-24  14  2.1        60.8
# 1635           Kelly Olynyk               DET  2021-22  11  0.5        56.7
# 2237          Rui Hachimura               LAL  2022-23  14  2.3        53.7
# 1430             Chris Paul               PHX  2021-22  29  3.1        52.0
# 1554              Ish Smith               WAS  2021-22  10  2.3        51.2
# 1146    Juancho Hernangomez               MIN  2020-21  12  1.6        49.0
# 745              Malik Monk               CHA  2019-20  13  0.8        47.0
# 1389        Bismack Biyombo               PHX  2021-22  10  1.4        45.2
# 1282            Robin Lopez               WAS  2020-21  11  3.8        45.0
# 1069         Gordon Hayward               CHA  2020-21  20  3.1        44.9
# 2556             Josh Green               DAL  2023-24  17  2.0        42.8
# 2094  Juan Toscano-Anderson               UTA  2022-23  11  1.5        42.5
# 2695          Peyton Watson               DEN  2023-24  18  1.1        42.5
# 1283            Rodney Hood               TOR  2020-21  12  1.8        42.4
# 1256        P.J. Washington               CHA  2020-21  20  2.9        42.1
# 2424       Dereck Lively II               DAL  2023-24  17  2.4        41.8
# 2148           Luke Kennard               MEM  2022-23  19  1.9        40.7
# 1483           Devin Booker               PHX  2021-22  32  3.0        39.9
# 1562            Jae Crowder               PHX  2021-22  30  3.1        39.8
# 1975         Doug McDermott               SAS  2022-23  12  1.9        39.4
# 633          JaMychal Green               LAC  2019-20  15  2.4        39.0
# 578            Dwayne Bacon               CHA  2019-20  10  2.6        38.6
# 2200           Ochai Agbaji               UTA  2022-23  20  2.5        38.5
# 746              Marc Gasol               TOR  2019-20  18  2.6        38.2
# 553         Dennis Schröder               OKC  2019-20  39  3.2        37.8
# 1077      Immanuel Quickley               NYK  2020-21  23  2.8        37.8
# 2746   Trayce Jackson-Davis               GSW  2023-24  13  1.6        37.7
# 908           Aaron Holiday               IND  2020-21  12  2.2        37.5
# 1937         Daniel Gafford               WAS  2022-23  17  1.7        37.3
# 2595              Kris Dunn               UTA  2023-24  13  2.2        36.8
# 2513           Jamal Murray               DEN  2023-24  25  3.1        36.8
# 572        Donte DiVincenzo               MIL  2019-20  17  1.9        36.5
# 114        Domantas Sabonis               IND  2018-19  22  1.7        36.2
# 1541       Hassan Whiteside               UTA  2021-22  10  0.5        36.1
# 1954              Dean Wade               CLE  2022-23  12  1.7        36.1
# 751           Mario Hezonja               POR  2019-20  10  1.7        35.4
# 747         Marco Belinelli               SAS  2019-20  16  2.2        35.2
# 1188            LaMelo Ball               CHA  2020-21  18  2.4        35.2
# 2180          Moritz Wagner               ORL  2022-23  12  2.4        35.1
# 1705          Mikal Bridges               PHX  2021-22  39  3.0        35.0
# 1751       Precious Achiuwa               TOR  2021-22  17  2.5        34.9
# 434          Victor Oladipo               IND  2018-19  15  3.4        34.8
# 1417        Cameron Johnson               PHX  2021-22  25  1.7        34.6
# 2460         Gary Payton II               GSW  2023-24  14  1.5        34.5
# 640            Jakob Poeltl               SAS  2019-20  13  2.5        34.0
# 1720          Nassir Little               POR  2021-22  12  2.2        33.9
# 803         Pat Connaughton               MIL  2019-20  13  2.1        33.7
# 804        Patrick Beverley               LAC  2019-20  17  3.2        33.4
# 1470          Deandre Ayton               PHX  2021-22  28  3.2        33.4
# 859       Terrance Ferguson               OKC  2019-20  22  3.2        33.0
#
#       OFF_RATING  DEF_RATING  USG_PCT  TS_PCT    PIE
# 2325       140.0        79.2    0.125   0.788  0.216
# 1635       140.0        83.3    0.250   0.798 -0.080
# 2237       136.8        83.0    0.114   0.438  0.067
# 1430       138.4        86.4    0.303   0.689  0.300
# 1554       130.2        78.9    0.190   0.551  0.155
# 1146       135.7        86.7    0.100   0.769  0.155
# 745        137.5        90.5    0.171   0.583  0.141
# 1389       135.5        90.3    0.222   0.847  0.209
# 1282       129.7        84.7    0.147   0.795  0.178
# 1069       138.0        93.1    0.272   0.606  0.213
# 2556       141.3        98.6    0.157   0.727  0.160
# 2094       150.0       107.5    0.068   1.042  0.067
# 2695       119.0        76.6    0.149   0.403  0.074
# 1283       131.5        89.1    0.085   0.500 -0.024
# 1256       142.1       100.0    0.123   0.384  0.031
# 2424       137.5        95.7    0.048   0.840  0.120
# 2148       130.5        89.7    0.088   0.887  0.081
# 1483       135.4        95.5    0.295   0.708  0.211
# 1562       132.5        92.7    0.121   0.672  0.124
# 1975       132.8        93.3    0.141   0.644  0.116
# 633        143.0       104.1    0.144   0.595  0.060
# 578        111.8        73.2    0.207   0.575  0.079
# 2200       131.7        93.2    0.193   0.635  0.106
# 746        126.0        87.8    0.088   0.217  0.050
# 553        123.2        85.3    0.217   0.635  0.119
# 1077       125.0        87.2    0.182   0.568  0.119
# 2746       135.6        97.9    0.057   1.000  0.099
# 908        137.5       100.0    0.154   0.759  0.126
# 1937       115.5        78.2    0.127   0.742  0.310
# 2595       140.4       103.5    0.068   0.600  0.077
# 2513       131.5        94.7    0.250   0.692  0.216
# 572        123.4        86.8    0.078   0.500  0.072
# 114        131.0        94.8    0.137   0.919  0.198
# 1541       171.4       135.3    0.444   0.667 -0.016
# 1954       123.9        87.8    0.056   0.521  0.045
# 751        123.8        88.4    0.021   0.000  0.014
# 747        121.5        86.3    0.152   0.684  0.120
# 1188       128.9        93.6    0.167   0.510  0.125
# 2180       120.3        85.2    0.143   0.610  0.163
# 1705       132.6        97.6    0.131   0.706  0.108
# 1751       132.6        97.7    0.157   0.329 -0.047
# 434        131.8        97.0    0.402   0.804  0.397
# 1417       127.6        93.0    0.122   0.863  0.148
# 2460       127.3        92.7    0.125   0.643  0.079
# 640        121.9        87.9    0.062   0.315  0.054
# 1720       128.8        94.9    0.065   0.630  0.050
# 803        111.3        77.6    0.076   0.595  0.115
# 804        132.5        99.1    0.094   0.568  0.088
# 1470       136.1       102.8    0.137   0.826  0.121
# 859        127.4        94.4    0.046   0.300 -0.030
# Saved top performers to top_clutch_performers_2018-2023.csv
# Saved complete dataset to all_clutch_data_2018-2023.csv

# %%
all_data[all_data['PLAYER_NAME'] == 'Aaron Gordon'].groupby(['PLAYER_NAME', 'SEASON']).agg({
    'NET_RATING': 'mean',
    'GP': 'sum',
    'MIN': 'sum'
}).reset_index()
# Out:
#     PLAYER_NAME   SEASON  NET_RATING  GP  MIN
# 0  Aaron Gordon  2018-19        -0.4  43  2.9
# 1  Aaron Gordon  2019-20        -6.6  27  3.3
# 2  Aaron Gordon  2020-21         7.7  19  2.9
# 3  Aaron Gordon  2021-22        11.0  32  4.0
# 4  Aaron Gordon  2022-23        16.0  28  3.7
# 5  Aaron Gordon  2023-24        19.4  38  3.2

# %% [markdown]
# # Select Top 10 Clutch Players Based on +/-

# %%
# Example usage
# Get data for multiple seasons
start_year = 1990
end_year = 2025
all_data = process_multiple_seasons(start_year=start_year, end_year=end_year)

if not all_data.empty:
    # Get top clutch performers across all seasons (min 10 games)
    top_performers = get_top_clutch_performers(all_data, n=10, min_games=10, min_min=2.5)
    
    print(f"\nTop 10 Clutch Performers (2000-2023) with at least 10 clutch games:")
    print(top_performers)
    
    # Save only the final results
    final_filename = f"top_clutch_performers_{start_year}_{end_year}.csv"
    top_performers.to_csv(final_filename, index=False)
    print(f"Saved top performers to {final_filename}")
    
    # # Also save the complete dataset
    complete_filename = f"all_clutch_data_{start_year}-{end_year}.csv"
    all_data.to_csv(complete_filename, index=False)
    print(f"Saved complete dataset to {complete_filename}")
# Out:
# === Processing 1990-91 season ===
# Fetching clutch stats for season 1990-91...
# Error getting clutch stats for season 1990-91: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# No data collected for 1990-91
#
# === Processing 1991-92 season ===
# Fetching clutch stats for season 1991-92...
# Traceback (most recent call last):
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/connection.py", line 516, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py", line 1428, in getresponse
#     response.begin()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py", line 1252, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py", line 1104, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/util/util.py", line 39, in reraise
#     raise value
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/connectionpool.py", line 536, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/urllib3/connectionpool.py", line 367, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/dh/rgyf9n3d4zl21r276r0z0bhh0000gn/T/ipykernel_90189/4215454972.py", line 21, in get_clutch_stats_for_season
#     clutch_stats = leaguedashplayerclutch.LeagueDashPlayerClutch(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/nba_api/stats/endpoints/leaguedashplayerclutch.py", line 202, in __init__
#     self.get_request()
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/nba_api/stats/endpoints/leaguedashplayerclutch.py", line 205, in get_request
#     self.nba_response = NBAStatsHTTP().send_api_request(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/nba_api/library/http.py", line 160, in send_api_request
#     response = self.get_session().get(
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/estebansanchez/Desktop/nba_clutch_players_202503/.nba_clutch/lib/python3.12/site-packages/requests/adapters.py", line 713, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Found 0 players with ≥1 clutch minutes in 1991-92 (filtered from 0 total)
# No data collected for 1991-92
#
# === Processing 1992-93 season ===
# Fetching clutch stats for season 1992-93...
# Found 0 players with ≥1 clutch minutes in 1992-93 (filtered from 0 total)
# No data collected for 1992-93
#
# === Processing 1993-94 season ===
# Fetching clutch stats for season 1993-94...
# Found 0 players with ≥1 clutch minutes in 1993-94 (filtered from 0 total)
# No data collected for 1993-94
#
# === Processing 1994-95 season ===
# Fetching clutch stats for season 1994-95...
# Found 0 players with ≥1 clutch minutes in 1994-95 (filtered from 0 total)
# No data collected for 1994-95
#
# === Processing 1995-96 season ===
# Fetching clutch stats for season 1995-96...
# Found 0 players with ≥1 clutch minutes in 1995-96 (filtered from 0 total)
# No data collected for 1995-96
#
# === Processing 1996-97 season ===
# Fetching clutch stats for season 1996-97...
# Found 343 players with ≥1 clutch minutes in 1996-97 (filtered from 393 total)
# Added 343 players from 1996-97 to dataset
# Waiting 2.58 seconds before next season...
#
# === Processing 1997-98 season ===
# Fetching clutch stats for season 1997-98...
# Found 341 players with ≥1 clutch minutes in 1997-98 (filtered from 392 total)
# Added 341 players from 1997-98 to dataset
# Waiting 3.95 seconds before next season...
#
# === Processing 1998-99 season ===
# Fetching clutch stats for season 1998-99...
# Found 320 players with ≥1 clutch minutes in 1998-99 (filtered from 366 total)
# Added 320 players from 1998-99 to dataset
# Waiting 3.33 seconds before next season...
#
# === Processing 1999-00 season ===
# Fetching clutch stats for season 1999-00...
# Found 359 players with ≥1 clutch minutes in 1999-00 (filtered from 400 total)
# Added 359 players from 1999-00 to dataset
# Waiting 3.80 seconds before next season...
#
# === Processing 2000-01 season ===
# Fetching clutch stats for season 2000-01...
# Found 352 players with ≥1 clutch minutes in 2000-01 (filtered from 390 total)
# Added 352 players from 2000-01 to dataset
# Waiting 3.03 seconds before next season...
#
# === Processing 2001-02 season ===
# Fetching clutch stats for season 2001-02...
# Found 353 players with ≥1 clutch minutes in 2001-02 (filtered from 398 total)
# Added 353 players from 2001-02 to dataset
# Waiting 3.10 seconds before next season...
#
# === Processing 2002-03 season ===
# Fetching clutch stats for season 2002-03...
# Found 339 players with ≥1 clutch minutes in 2002-03 (filtered from 386 total)
# Added 339 players from 2002-03 to dataset
# Waiting 2.53 seconds before next season...
#
# === Processing 2003-04 season ===
# Fetching clutch stats for season 2003-04...
# Found 350 players with ≥1 clutch minutes in 2003-04 (filtered from 388 total)
# Added 350 players from 2003-04 to dataset
# Waiting 2.08 seconds before next season...
#
# === Processing 2004-05 season ===
# Fetching clutch stats for season 2004-05...
# Found 384 players with ≥1 clutch minutes in 2004-05 (filtered from 417 total)
# Added 384 players from 2004-05 to dataset
# Waiting 2.30 seconds before next season...
#
# === Processing 2005-06 season ===
# Fetching clutch stats for season 2005-06...
# Found 380 players with ≥1 clutch minutes in 2005-06 (filtered from 418 total)
# Added 380 players from 2005-06 to dataset
# Waiting 3.50 seconds before next season...
#
# === Processing 2006-07 season ===
# Fetching clutch stats for season 2006-07...
# Found 365 players with ≥1 clutch minutes in 2006-07 (filtered from 413 total)
# Added 365 players from 2006-07 to dataset
# Waiting 3.86 seconds before next season...
#
# === Processing 2007-08 season ===
# Fetching clutch stats for season 2007-08...
# Found 353 players with ≥1 clutch minutes in 2007-08 (filtered from 401 total)
# Added 353 players from 2007-08 to dataset
# Waiting 2.61 seconds before next season...
#
# === Processing 2008-09 season ===
# Fetching clutch stats for season 2008-09...
# Found 357 players with ≥1 clutch minutes in 2008-09 (filtered from 401 total)
# Added 357 players from 2008-09 to dataset
# Waiting 3.46 seconds before next season...
#
# === Processing 2009-10 season ===
# Fetching clutch stats for season 2009-10...
# Found 358 players with ≥1 clutch minutes in 2009-10 (filtered from 404 total)
# Added 358 players from 2009-10 to dataset
# Waiting 2.71 seconds before next season...
#
# === Processing 2010-11 season ===
# Fetching clutch stats for season 2010-11...
# Found 361 players with ≥1 clutch minutes in 2010-11 (filtered from 408 total)
# Added 361 players from 2010-11 to dataset
# Waiting 3.20 seconds before next season...
#
# === Processing 2011-12 season ===
# Fetching clutch stats for season 2011-12...
# Found 382 players with ≥1 clutch minutes in 2011-12 (filtered from 434 total)
# Added 382 players from 2011-12 to dataset
# Waiting 2.96 seconds before next season...
#
# === Processing 2012-13 season ===
# Fetching clutch stats for season 2012-13...
# Found 366 players with ≥1 clutch minutes in 2012-13 (filtered from 423 total)
# Added 366 players from 2012-13 to dataset
# Waiting 2.61 seconds before next season...
#
# === Processing 2013-14 season ===
# Fetching clutch stats for season 2013-14...
# Found 389 players with ≥1 clutch minutes in 2013-14 (filtered from 435 total)
# Added 389 players from 2013-14 to dataset
# Waiting 2.58 seconds before next season...
#
# === Processing 2014-15 season ===
# Fetching clutch stats for season 2014-15...
# Found 394 players with ≥1 clutch minutes in 2014-15 (filtered from 445 total)
# Added 394 players from 2014-15 to dataset
# Waiting 2.19 seconds before next season...
#
# === Processing 2015-16 season ===
# Fetching clutch stats for season 2015-16...
# Found 384 players with ≥1 clutch minutes in 2015-16 (filtered from 436 total)
# Added 384 players from 2015-16 to dataset
# Waiting 3.79 seconds before next season...
#
# === Processing 2016-17 season ===
# Fetching clutch stats for season 2016-17...
# Found 393 players with ≥1 clutch minutes in 2016-17 (filtered from 434 total)
# Added 393 players from 2016-17 to dataset
# Waiting 3.15 seconds before next season...
#
# === Processing 2017-18 season ===
# Fetching clutch stats for season 2017-18...
# Found 391 players with ≥1 clutch minutes in 2017-18 (filtered from 450 total)
# Added 391 players from 2017-18 to dataset
# Waiting 2.40 seconds before next season...
#
# === Processing 2018-19 season ===
# Fetching clutch stats for season 2018-19...
# Found 393 players with ≥1 clutch minutes in 2018-19 (filtered from 451 total)
# Added 393 players from 2018-19 to dataset
# Waiting 2.97 seconds before next season...
#
# === Processing 2019-20 season ===
# Fetching clutch stats for season 2019-20...
# Found 403 players with ≥1 clutch minutes in 2019-20 (filtered from 456 total)
# Added 403 players from 2019-20 to dataset
# Waiting 3.60 seconds before next season...
#
# === Processing 2020-21 season ===
# Fetching clutch stats for season 2020-21...
# Found 409 players with ≥1 clutch minutes in 2020-21 (filtered from 454 total)
# Added 409 players from 2020-21 to dataset
# Waiting 3.31 seconds before next season...
#
# === Processing 2021-22 season ===
# Fetching clutch stats for season 2021-22...
# Found 435 players with ≥1 clutch minutes in 2021-22 (filtered from 496 total)
# Added 435 players from 2021-22 to dataset
# Waiting 3.58 seconds before next season...
#
# === Processing 2022-23 season ===
# Fetching clutch stats for season 2022-23...
# Found 405 players with ≥1 clutch minutes in 2022-23 (filtered from 451 total)
# Added 405 players from 2022-23 to dataset
# Waiting 3.60 seconds before next season...
#
# === Processing 2023-24 season ===
# Fetching clutch stats for season 2023-24...
# Found 414 players with ≥1 clutch minutes in 2023-24 (filtered from 469 total)
# Added 414 players from 2023-24 to dataset
# Waiting 2.85 seconds before next season...
#
# === Processing 2024-25 season ===
# Fetching clutch stats for season 2024-25...
# Found 382 players with ≥1 clutch minutes in 2024-25 (filtered from 443 total)
# Added 382 players from 2024-25 to dataset
# Waiting 3.36 seconds before next season...
#
# === Processing 2025-26 season ===
# Fetching clutch stats for season 2025-26...
# Found 0 players with ≥1 clutch minutes in 2025-26 (filtered from 0 total)
# No data collected for 2025-26
#
# Total: 10855 player-season records across 29 seasons
# Filtering for players with at least 10 clutch games
# Before: 10855 players, After: 5867 players
#
# Top 10 Clutch Performers (2000-2023) with at least 10 clutch games:
#               PLAYER_NAME TEAM_ABBREVIATION   SEASON  GP  MIN  NET_RATING  \
# 9281           Chris Paul               PHX  2021-22  29  3.1        52.0
# 7670           Chris Paul               HOU  2017-18  21  2.6        50.1
# 6222         Jared Dudley               LAC  2013-14  17  3.2        48.0
# 6359          Patty Mills               SAS  2013-14  13  3.6        47.6
# 4595   Zydrunas Ilgauskas               CLE  2008-09  18  2.5        47.2
# 7096        Mario Hezonja               ORL  2015-16  11  2.8        46.6
# 10589         Evan Mobley               CLE  2024-25  22  2.9        46.0
# 5828           Greg Smith               HOU  2012-13  10  2.8        45.4
# 9148          Robin Lopez               WAS  2020-21  11  3.8        45.0
# 8957       Gordon Hayward               CHA  2020-21  20  3.1        44.9
#
#        OFF_RATING  DEF_RATING  USG_PCT  TS_PCT    PIE
# 9281        138.4        86.4    0.303   0.689  0.300
# 7670        145.5        95.5    0.324   0.797  0.302
# 6222        126.7        78.7    0.071   0.788  0.082
# 6359        119.2        71.6    0.223   0.558  0.193
# 4595        135.9        88.6    0.165   0.716  0.070
# 7096        116.4        69.8    0.263   0.766  0.206
# 10589       148.3       102.2    0.121   0.799  0.118
# 5828        118.8        73.3    0.097   0.962  0.261
# 9148        129.7        84.7    0.147   0.795  0.178
# 8957        138.0        93.1    0.272   0.606  0.213
# Saved top performers to top_clutch_performers_1990_2025.csv
# Saved complete dataset to all_clutch_data_1990-2025.csv

# %%
top_performers
# Out:
#               PLAYER_NAME TEAM_ABBREVIATION   SEASON  GP  MIN  NET_RATING  \
# 9281           Chris Paul               PHX  2021-22  29  3.1        52.0
# 7670           Chris Paul               HOU  2017-18  21  2.6        50.1
# 6222         Jared Dudley               LAC  2013-14  17  3.2        48.0
# 6359          Patty Mills               SAS  2013-14  13  3.6        47.6
# 4595   Zydrunas Ilgauskas               CLE  2008-09  18  2.5        47.2
# 7096        Mario Hezonja               ORL  2015-16  11  2.8        46.6
# 10589         Evan Mobley               CLE  2024-25  22  2.9        46.0
# 5828           Greg Smith               HOU  2012-13  10  2.8        45.4
# 9148          Robin Lopez               WAS  2020-21  11  3.8        45.0
# 8957       Gordon Hayward               CHA  2020-21  20  3.1        44.9
#
#        OFF_RATING  DEF_RATING  USG_PCT  TS_PCT    PIE
# 9281        138.4        86.4    0.303   0.689  0.300
# 7670        145.5        95.5    0.324   0.797  0.302
# 6222        126.7        78.7    0.071   0.788  0.082
# 6359        119.2        71.6    0.223   0.558  0.193
# 4595        135.9        88.6    0.165   0.716  0.070
# 7096        116.4        69.8    0.263   0.766  0.206
# 10589       148.3       102.2    0.121   0.799  0.118
# 5828        118.8        73.3    0.097   0.962  0.261
# 9148        129.7        84.7    0.147   0.795  0.178
# 8957        138.0        93.1    0.272   0.606  0.213

# %% [markdown]
# # Analyze Players to pin point attributes

# %%
print(f'Players: {set(player for player in top_performers.PLAYER_NAME.values)}')
# Out:
# Players: {'Zydrunas Ilgauskas', 'Robin Lopez', 'Jared Dudley', 'Greg Smith', 'Patty Mills', 'Chris Paul', 'Mario Hezonja', 'Evan Mobley', 'Gordon Hayward'}

# %% [markdown]
# ### `Chris Paul`

# %% [markdown]
# Lets begin with someone who appears twice on the list. Lets see what makes CP3 such a clutch player. First of all, lets analyze how good he actually is, and compare his `NET_RATING` to more time than just clutch minutes. Also we should compare to the playoffs.

# %% [markdown]
# ### `Zydrunas Ilgauskas`

# %% [markdown]
# ### `Robin Lopez`

# %% [markdown]
# ### `Jared Dudley`

# %% [markdown]
# ### `Greg Smith`

# %% [markdown]
# ### `Patty Mills`

# %% [markdown]
# ### `Evan Mobley`

# %% [markdown]
# ### `Gordon Hayward`

# %% [markdown]
# ### `Mario Hezonja`
